# %%
import pandas as pd
df = pd.read_excel("./biblio_data_series.xlsx")
# 데이터 확인
df.head(5)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            국가서지번호      출처기관제어번호   자료유형  \
# 0  NBC20210087876  KSE201500498  연속간행물
# 1  NBC20210087877  KSE201500498  연속간행물
# 2  NBC20210087878  KSE201500498  연속간행물
# 3  NBC20210087879  KSE201500498  연속간행물
# 4  NBC20210087880  KSE201900794  연속간행물
#
#                                표제와 책임표시사항           제목  부제목  편제          권차  \
# 0  (ACTS) 신학저널 = ACTS theological journal  (ACTS) 신학저널  NaN NaN      Vol.47
# 1  (ACTS) 신학저널 = ACTS theological journal  (ACTS) 신학저널  NaN NaN      Vol.48
# 2  (ACTS) 신학저널 = ACTS theological journal  (ACTS) 신학저널  NaN NaN  Vol.49(영문)
# 3  (ACTS) 신학저널 = ACTS theological journal  (ACTS) 신학저널  NaN NaN      Vol.50
# 4                              (An) usual   (An) usual  NaN NaN     Vol. 11
#
#                  저자  판사항  ...          접근정보 번역 번역원어 정부기관부호 정부간행물등록번호       출처  \
# 0  아세아연합신학대학교.신학연구소  NaN  ...  소장 : 국립중앙도서관  N  NaN    NaN       NaN  국립중앙도서관
# 1  아세아연합신학대학교.신학연구소  NaN  ...  소장 : 국립중앙도서관  N  NaN    NaN       NaN  국립중앙도서관
# 2  아세아연합신학대학교.신학연구소  NaN  ...  소장 : 국립중앙도서관  N  NaN    NaN       NaN  국립중앙도서관
# 3  아세아연합신학대학교.신학연구소  NaN  ...  소장 : 국립중앙도서관  N  NaN    NaN       NaN  국립중앙도서관
# 4            스튜디오봄봄  NaN  ...  소장 : 국립중앙도서관  N  NaN    NaN       NaN  국립중앙도서관
#
#                   간행빈도           권차/연월차       ISSN  \
# 0  계간,Vol.19(2014년4월)-    Vol.18(2013)-  2383-4943
# 1  계간,Vol.19(2014년4월)-    Vol.18(2013)-  2383-4943
# 2  계간,Vol.19(2014년4월)-    Vol.18(2013)-  2383-4943
# 3  계간,Vol.19(2014년4월)-    Vol.18(2013)-  2383-4943
# 4                   계간  Vol.1(2019년6월)-  2671-5465
#
#                              소장사항
# 0    Vol.18(2013)-Vol.51(2022년4월)
# 1    Vol.18(2013)-Vol.51(2022년4월)
# 2    Vol.18(2013)-Vol.51(2022년4월)
# 3    Vol.18(2013)-Vol.51(2022년4월)
# 4  Vol.1(2019년6월)-Vol.12(2021년5월)
#
# [5 rows x 46 columns]

# %%
data = df.loc[:,['출처기관제어번호', '자료유형', '제목', '부제목', '저자', '발행처', '발행지역',  '발행년', '내용유형', '크기','본문언어','가격' ,'분야']]

# %%
# 데이터프레임의 데이터 유형 확인
data.dtypes
# Out:
# 출처기관제어번호     object
# 자료유형         object
# 제목           object
# 부제목          object
# 저자           object
# 발행처          object
# 발행지역         object
# 발행년          object
# 내용유형         object
# 크기           object
# 본문언어         object
# 가격          float64
# 분야           object
# dtype: object

# %%
data['분야'].value_counts().head(10)
# Out:
# 경제학                  2157
# 의학                   2055
# 행정학                  1551
# 한국문학                 1499
# 사회학,사회문제             1144
# 교육학                  1098
# 기독교                   971
# 아시아                   857
# 공학,공업일반,토목공학,환경공학     745
# 농업,농학                 690
# Name: 분야, dtype: int64

# %%
print(len(data))
# Out:
# 20321

# %%
data.sort_values(by='발행년', ascending=False)
# Out:
#            출처기관제어번호   자료유형                                            제목  \
# 5176   KSE200700167  연속간행물                                       土地補償法硏究
# 4418   KSE202101879  연속간행물                              Trade & Security
# 17238  KSE202100535  연속간행물                                        콜드체인뉴스
# 10098  KSE202101676  연속간행물                                          도시연구
# 1289   KSE202100634  연속간행물                                Alpinist Korea
# ...             ...    ...                                           ...
# 20320  KSE201600346  연속간행물                                           茶文化
# 1242   KSE200301846  연속간행물  Advanced studies in contemporary mathematics
# 1243   KSE200301846  연속간행물  Advanced studies in contemporary mathematics
# 1241   KSE200301846  연속간행물  Advanced studies in contemporary mathematics
# 1244   KSE200301846  연속간행물  Advanced studies in contemporary mathematics
#
#               부제목                                                 저자  \
# 5176      No data                                         한국토지보상법연구회
# 4418   무역안보 전문 저널                                            전략물자관리원
# 17238     No data                                             콜드체인뉴스
# 10098     No data                                              인천연구원
# 1289      No data                                              마운틴저널
# ...           ...                                                ...
# 20320     No data                                            한국차문화협회
# 1242      No data  Jangjeon Research Institute for Mathematical S...
# 1243      No data  Jangjeon Research Institute for Mathematical S...
# 1241      No data  Jangjeon Research Institute for Mathematical S...
# 1244      No data  Jangjeon Research Institute for Mathematical S...
#
#                                                      발행처 발행지역    발행년  내용유형  \
# 5176                                          한국토지보상법연구회   서울  [200-  text
# 4418                                             전략물자관리원   서울  2021-  text
# 17238                                             콜드체인뉴스   서울  2021-  text
# 10098                                              인천연구원   인천  2021-  text
# 1289                                               마운틴저널   서울  2021-  text
# ...                                                  ...  ...    ...   ...
# 20320                                            한국차문화협회   서울      -  text
# 1242   Jangjeon Research Institute for Mathematical S...   대구         text
# 1243   Jangjeon Research Institute for Mathematical S...   대구         text
# 1241   Jangjeon Research Institute for Mathematical S...   대구         text
# 1244   Jangjeon Research Institute for Mathematical S...   대구         text
#
#           크기 본문언어       가격         분야
# 5176   23 cm  kor  20000.0         법학
# 4418   27 cm  kor  No data        경제학
# 17238  30 cm  kor  10000.0        경제학
# 10098  26 cm  kor  No data        아시아
# 1289   28 cm  kor  30000.0     오락,스포츠
# ...      ...  ...      ...        ...
# 20320  24 cm  kor  No data  풍습,예절,민속학
# 1242   26 cm  eng  No data         수학
# 1243   26 cm  eng  No data         수학
# 1241   26 cm  eng  No data         수학
# 1244   26 cm  eng  No data         수학
#
# [20321 rows x 13 columns]

# %%
data[data['제목'].str.contains('Journal of Asian finance, economics and business')]
# Out:
#           출처기관제어번호   자료유형                                                제목  \
# 2719  KSE201400776  연속간행물  Journal of Asian finance, economics and business
#
#         부제목                                      저자  \
# 2719  JAFEB  Korea Distribution Science Association
#
#                                          발행처      발행지역    발행년  내용유형     크기  \
# 2719  Korea Distribution Science Association  Seongnam  2014-  text  28 cm
#
#      본문언어        가격   분야
# 2719  eng  500000.0  경제학

# %%
import re


# 대괄호를 제거하는 정규식 패턴
pattern = r'\[.*?\]'

# 대괄호 제거
data['발행지역'] = [re.sub(pattern, '', location) for location in data['발행지역']]
data['발행지역'] = [location[:-1] if location.endswith('군') else location for location in data['발행지역']]
print(data['발행지역'])
# Out:
# 0        양평
# 1        양평
# 2        양평
# 3        양평
# 4        서울
#          ..
# 20316    서울
# 20317    서울
# 20318    서울
# 20319    서울
# 20320    서울
# Name: 발행지역, Length: 20321, dtype: object

# %%
data['발행지역'] = data['발행지역'].str.replace(r'^Seoul.*', '서울', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Anseong.*', '안성', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[목포].*', '목포', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Jeonju.*', '전주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[여주].*', '여주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[담양군].*', '담양', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[목포].*', '목포', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^완주군서울.*', '완주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^울산영암군.*', '울산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[진주].*', '진주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[파주].*', '파주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[청주].*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^서울:.*', '서울', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^포천군.*', '포천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[여주].*', '여주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[김해].*', '김해', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^서울.*', '서울', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^남제주군.*', '제주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[대전][서울].*', '대전', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^정읍시.*', '정읍', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^경산군.*', '경산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^용인시.*', '용인', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^대전서울.*', '대전', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^양주시.*', '양주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^안성시.*', '안성', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[창원].*', '창원', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[춘천].*', '춘천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[부산].*', '부산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^광주시.*', '광주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^청주시.*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[파주].*', '파주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[청주].*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[대구].*', '대구', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[경남].*', '경남', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[남해군].*', '남해', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[김해].*', '김해', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[화성].*', '화성', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^과천인천.*', '과천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[진주].*', '진주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[담양군].*', '담양', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Jeonju.*', '전주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^[여주].*', '여주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Daejeon.*', '대전', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Busan.*', '부산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Chungju.*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^광주시.*', '광주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^청주시.*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Asan.*', '아산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Jinju.*', '진주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Suwon.*', '수원', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Seongnam.*', '성남', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^새종.*', '세종', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^濟州.*', '제주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Sejong.*', '세종', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Anyang.*', '안양', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Daegu.*', '대구', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^과천.*', '과천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Yongin.*', '영진', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Wonju.*', '원주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Gwangju.*', '광주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^仁川.*', '인천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Gwacheon.*', '과천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Masan.*', '마산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Incheon.*', '인천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Andong.*', '안동', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Cheongju.*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Gyeongsan.*', '경산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Guri.*', '구리', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^釜山.*', '부산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Anyang.*', '안양', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Cheonan.*', '천안', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Jeju.*', '제주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^강원도.*', '강원', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^인천.*', '인천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Ulsan.*', '울산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Tongyeong.*', '통영', regex=True)

data['발행지역'] = data['발행지역'].str.replace(r'^광명시.*', '광명', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^ソウル.*', '서울', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^軍威郡.*', '군위', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'\(경기도\)$', '(경기)')
data['발행지역'] = data['발행지역'].str.replace(r'^愛知.*', '아이치현', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^영주시.*', '영주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^高城郡.*', '고성', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^제주국보문인협회.*', '제주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Goyang.*', '고양', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Daejon.*', '대전', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Gunsan.*', '군산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Seogwipo.*', '서귀포', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^愛知.*', '아이치현', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^慶山.*', '경산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^南海.*', '남해', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^首尔.*', '서울', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Ansan.*', '안산', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Daejon.*', '대전', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Chuncheon.*', '춘천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^光州.*', '광주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^大邱.*', '대구', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^ .*', '발행지불명', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Pocheon.*', '포천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Hwaseong.*', '화성', regex=True)

data['발행지역'] = data['발행지역'].str.replace(r'^Seocheon.*', '서천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Suncheon.*', '순천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Тэгу.*', '대구', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^光州.*', '광주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^淸州.*', '청주', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^ .*', '발행지불명', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Pocheon.*', '포천', regex=True)
data['발행지역'] = data['발행지역'].str.replace(r'^Hwaseong.*', '화성', regex=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_36760\829243063.py:81: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['발행지역'] = data['발행지역'].str.replace(r'\(경기도\)$', '(경기)')

# %%
data['발행지역'].unique()
# Out:
# array(['담양', '서울', '안성', '광주', '대구', '의왕', '전주', '대전', '부산', '청주', '아산',
#        '진주', '수원', '성남', '화성', '시흥', '고창', '강릉', '고성', '동해', '삼척', '속초',
#        '영월', '창원', '인제', '정선', '철원', '춘천', '태백', '평창', '홍천', '횡성', '인천',
#        '가평', '고양', '과천', '광명', '김해', '경남', '동두천', '안산', '안양', '여주', '연천',
#        '오산', '용인', '의정부', '이천', '파주', '평택', '목포', '하남', '광주(경기)', '거제',
#        '거창', '밀양', '사천', '의령', '마산', '통영', '하동', '함안', '함양', '합천', '고령',
#        '문경', '봉화', '상주', '안동', '영덕', '영양', '영주', '영천', '예천', '울릉', '울진',
#        '의성', '칠곡', '충북', '나주', '', '광양', '제주', '세종', '무안', '익산', '울산',
#        '울주', '옹진', '강진', '고흥', '곡성', '보성', '순천', '신안', '영광', '영암', '완도',
#        '장성', '장흥', '함평', '무주', '순창', '완주', '임실', '장수', '정읍', '서귀포', '계룡',
#        '공주', '금산', '논산', '당진', '보령', '서산', '서천', '예산', '태안', '홍성', '괴산',
#        '단양', '보은', '영동', '옥천', '음성', '제천', '증평', '충주', '원주', '영진', '경산',
#        '구리', '천안', '포천', '군산', '충남', '연기', '군위', '아이치현', '남해', '강화', '전북',
#        '강원', '기장', '로스엔젤레스', '발행지불명', '충무', '울산영암'], dtype=object)

# %%
data['발행지역'].value_counts().head(10)
# Out:
# 서울    11139
# 대구     1919
# 부산     1123
# 광주      404
# 인천      401
# 화성      365
# 청주      353
# 수원      323
# 춘천      265
# 경남      223
# Name: 발행지역, dtype: int64

# %%
# 대괄호를 제거하는 정규식 패턴
pattern = r'\[.*?\]'

# 대괄호 제거
data['발행년'] = [re.sub(pattern, '', location) for location in data['발행년']]
print(data['발행년'])
# Out:
# 0        2013-
# 1        2013-
# 2        2013-
# 3        2013-
# 4        2019-
#          ...
# 20316    1988-
# 20317        -
# 20318        -
# 20319        -
# 20320        -
# Name: 발행년, Length: 20321, dtype: object

# %%
data[data['발행년'] == '1918-']
# Out:
#           출처기관제어번호   자료유형    제목      부제목                          저자    발행처  \
# 6259  KSE199504448  연속간행물  神學指南  No data  신학지남사;조선평양장로회신학교;총신대학교.출판부  神學指南社
# 6260  KSE199504448  연속간행물  神學指南  No data  신학지남사;조선평양장로회신학교;총신대학교.출판부  神學指南社
# 6261  KSE199504448  연속간행물  神學指南  No data  신학지남사;조선평양장로회신학교;총신대학교.출판부  神學指南社
# 6262  KSE199504448  연속간행물  神學指南  No data  신학지남사;조선평양장로회신학교;총신대학교.출판부  神學指南社
#
#      발행지역    발행년  내용유형     크기 본문언어      가격   분야
# 6259   서울  1918-  text  23 cm  kor  9000.0  기독교
# 6260   서울  1918-  text  23 cm  kor  9000.0  기독교
# 6261   서울  1918-  text  23 cm  kor  9000.0  기독교
# 6262   서울  1918-  text  23 cm  kor  9000.0  기독교

# %%
from collections import Counter
import re

# 키워드 추출에 사용할 열 선택
selected_columns = ['제목', '부제목']

# 데이터프레임에서 '분야' 열의 고유값 추출
unique_fields = data['발행지역'].value_counts().head(5).index.tolist()

for name in unique_fields:
    # 데이터프레임에서 선택한 열 결합
    text_data = data[data['발행지역'] == name][selected_columns].fillna('').apply(lambda x: ' '.join(x), axis=1)

    # 키워드 추출 및 빈도 계산
    def extract_keywords(text):
        # 소문자 변환
        text = text.lower()
        # 정규표현식을 사용하여 단어 추출 (영문과 숫자만 포함)
        words = re.findall(r'\w+', text)
        return words

    # 모든 키워드 추출
    all_keywords = text_data.apply(extract_keywords)

    # 모든 키워드를 하나의 리스트로 결합
    all_keywords = [keyword for keywords in all_keywords for keyword in keywords]

    # 키워드 빈도 계산
    keyword_counts = Counter(all_keywords)

    # 가장 많이 나타난 키워드 10개 출력
    top_keywords = keyword_counts.most_common(10)

    # 결과 출력
    print(name + " 필드의 가장 많이 나타난 키워드 Top 60:")
    for keyword, count in top_keywords:
        print(f"{keyword}: {count}")
# Out:
# 서울 필드의 가장 많이 나타난 키워드 Top 60:
# of: 782
# journal: 705
# and: 345
# the: 271
# magazine: 240
# korean: 217
# korea: 182
# research: 128
# 위한: 119
# 논문집: 115
# 대구 필드의 가장 많이 나타난 키워드 Top 60:
# dvd: 378
# rom: 378
# 공보: 378
# 실: 302
# 공개특: 176
# 등록특: 126
# 점자판: 96
# 소식지: 89
# 디자인: 76
# 상표: 76
# 부산 필드의 가장 많이 나타난 키워드 Top 60:
# 부산: 80
# 다이내믹: 75
# of: 56
# journal: 45
# 부산광역시: 26
# magazine: 26
# 지역사회: 23
# 건강통계: 23
# 소식지: 21
# the: 20
# 광주 필드의 가장 많이 나타난 키워드 Top 60:
# 광주광역시: 24
# 인문사회: 24
# 21: 24
# 광주: 23
# of: 22
# journal: 18
# 소식지: 17
# 소식: 14
# the: 13
# 속삭임: 12
# 인천 필드의 가장 많이 나타난 키워드 Top 60:
# journal: 30
# 인천광역시: 18
# 인천애의회: 15
# of: 14
# ifez: 12
# 會議錄: 12
# 굿모닝: 12
# 인천: 12
# 시각장애인용: 12
# 화도진소식: 12

# %%
# 데이터프레임에서 '분야' 열의 고유값 추출
unique_fields = data['분야'].value_counts().head(10).index.tolist()

# 리스트 출력
print(unique_fields)
# Out:
# ['경제학', '의학', '행정학', '한국문학', '사회학,사회문제', '교육학', '기독교', '아시아', '공학,공업일반,토목공학,환경공학', '농업,농학']

# %%
for name in unique_fields:
    print(name)
# Out:
# 경제학
# 의학
# 행정학
# 한국문학
# 사회학,사회문제
# 교육학
# 기독교
# 아시아
# 공학,공업일반,토목공학,환경공학
# 농업,농학

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정 (Windows 환경에서는 다른 폰트를 사용할 수 있음)
font_path = "C:/Windows/Fonts/malgun.ttf"  # 사용할 한글 폰트 경로
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 본문언어 빈도 상위 10개 가져오기
top_languages = data['본문언어'].value_counts().head(10)

# 그래프 그리기
plt.figure(figsize=(10, 6))
ax = top_languages.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('도서 본문언어 상위 10개', fontsize=16)
plt.xlabel('본문언어', fontsize=12)
plt.ylabel('도서 개수', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 그래프에 개수 표시
for i, v in enumerate(top_languages):
    ax.text(i, v + 10, str(v), ha='center', va='bottom', fontsize=10)

plt.tight_layout()

# 그래프 표시
plt.show()

# %%
data.fillna('No data', inplace=True)

# %%
data.to_csv('biblio_data_series_updated_data.csv', index=False, encoding='utf-8-sig')
